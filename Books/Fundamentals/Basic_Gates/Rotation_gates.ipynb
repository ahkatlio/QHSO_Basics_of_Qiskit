# %% [markdown]
# <!DOCTYPE html>
# <html>
#
# <head>
#     <title>Rx, Ry, Rz</title>
#     <link href="https://fonts.googleapis.com/css?family=Jost&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Jost', sans-serif;
#         }
#         h1, h2, h3, h4, h5, h6, p, ul {
#             font-family: 'Jost', sans-serif;
#         }
#         h1{
#             color: orange;
#         }
#         h2 {
#             color: #8BC34A;
#         }
#         .center {
#             text-align: center;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="center">
#         <img src="Algorithms/Logo_for_all/logo_round.png" alt="QHSO Logo" width="100">
#     </div>
#     <h1 style="text-align: center;">Quantum Rotation Gates: Turning Quantum Bits with Precision</h1>
#     <p>In this notebook, we'll explore an exciting concept called "rotation gates." These gates are like magic wands that allow us to turn and twist quantum bits (qubits) in precise ways. Let's dive in!</p>
#     <h2>Let's see how Rotation Gates work</h2>
#     <p>But first we are going to create an empty Q-sphere.</p>
# </body>
#
# </html>

# %%
# Import the necessary functions from Qiskit
from qiskit.visualization import plot_state_qsphere
from qiskit import QuantumCircuit, Aer, execute
from math import pi

# Create a quantum circuit with one qubit
qc = QuantumCircuit(1)

# Execute the quantum circuit on a statevector simulator backend
backend = Aer.get_backend('statevector_simulator')
result = execute(qc, backend).result()

# Get the statevector of the quantum circuit
statevector = result.get_statevector(qc)

# Plot the statevector on the Bloch sphere
plot_state_qsphere(statevector, show_state_phases = True, use_degrees = True)

# %% [markdown]
# We can see the arrow is pointing up, which means the qubit is in the state |0⟩. Let's see what happens when we apply a rotation gate to this qubit. We want to rotate this arrow 90 degrees around the y-axis. We can do this by applying the Ry gate with a rotation angle of 90 degrees.

# %%
qc.ry(pi/2, 0)

# %% [markdown]
# Let's see how the circuit looks like:

# %%
qc.draw(output='mpl')

# %% [markdown]
# Lst's see how the Q-sphere looks like after applying the Ry gate:

# %%
backend = Aer.get_backend('statevector_simulator')
result = execute(qc, backend).result()
statevector = result.get_statevector(qc)
plot_state_qsphere(statevector, show_state_phases = True, use_degrees = True)

# %% [markdown]
# What if we want to rotate the qubit 60 degrees around the x-axis? We can do this by applying the Rx gate with a rotation angle of 60 degrees.

# %%
qc1 = QuantumCircuit(1)
qc1.rx(pi/3, 0)

# %% [markdown]
# Let's see how the circuit looks like:

# %%
qc1.draw(output='mpl')

# %% [markdown]
# Let's see how the Q-sphere looks like after applying the Rx gate:

# %%
backend = Aer.get_backend('statevector_simulator')
result = execute(qc1, backend).result()
statevector = result.get_statevector(qc1)
plot_state_qsphere(statevector, show_state_phases = True, use_degrees = True)

# %% [markdown]
# Now let's see what happens when we apply the Rz gate to the qubit. We want to rotate this arrow 180 degrees around the z-axis. We can do this by applying the Rz gate with a rotation angle of 180 degrees.

# %%
qc2 = QuantumCircuit(1)
qc2.rz(pi, 0)

# %% [markdown]
# Let's see how the circuit looks like:

# %%
qc2.draw(output='mpl')

# %% [markdown]
# Let's see how the bloch sphere looks like after applying the Rz gate:

# %%
backend = Aer.get_backend('statevector_simulator')
result = execute(qc2, backend).result()
statevector = result.get_statevector(qc2)
plot_state_qsphere(statevector, show_state_phases = True, use_degrees = True)

# %% [markdown]
# <!DOCTYPE html>
# <html>
#
# <head>
#     <link href="https://fonts.googleapis.com/css?family=Jost&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Jost', sans-serif;
#         }
#         h1, h2, h3, h4, h5, h6, p, ol {
#             font-family: 'Jost', sans-serif;
#         }
#         h1{
#             color: orange;
#         }
#         h2 {
#             color: #8BC34A;
#         }
#         .center {
#             text-align: center;
#         }
#         /* Define the button styles */
#         .button {
#             background-color: #4CAF50; /* Green */
#             border: none;
#             color: white;
#             padding: 15px 32px;
#             text-align: center;
#             text-decoration: none;
#             display: inline-block;
#             font-size: 16px;
#             margin: 4px auto; /* Center the button horizontally */
#             cursor: pointer;
#             transition-duration: 0.4s;
#             border-radius: 10px; /* Add rounded corners */
#             box-shadow: 0 5px #666; /* Add a shadow */
#         }
#         /* Define the hover effect */
#         .button:hover {
#             background-color: #008CBA; /* Blue */
#             color: white;
#         }
#         /* Define the active effect */
#         .button:active {
#             background-color: #3e8e41; /* Dark green */
#             box-shadow: 0 2px #666; /* Change the shadow */
#             transform: translateY(4px);
#         }
#     </style>
# </head>
#
# <body>
#     <h2>What's next?</h2>
#     <p>Fantastic job mastering rotation gates 👍! You've learned how to elegantly manipulate qubits in various directions. Now, let's expand your quantum toolkit even further as we introduce the Y gate.
#
# The Y gate is a quantum twist-master that operates differently from both the X (bit flip) and Z (phase flip) gates. In our upcoming notebook, we'll delve into the intriguing properties of the Y gate, uncover its unique effects on qubits, and explore how it fits into the grand tapestry of quantum computing.
#
# Get ready to embrace the world of the Y gate as we continue your quantum adventure!</p>
#     <div class="center"> <!-- Center the button vertically -->
#         <!-- Create the button element -->
#         <a href = "Y_gate.ipynb"><button class="button">Y gate</button></a>
#     </div>
# </body>
#
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
#
# <head>
#     <link href="https://fonts.googleapis.com/css?family=Jost&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Jost', sans-serif;
#         }
#         .created-by {
#          font-family: 'Jost', sans-serif;
#          text-align: center;
#          margin-top: 50px;
#         }
#         .created-by a {
#             color: #fff;
#             text-decoration: none;
#         }
#         .created-by a:hover {
#             color: #8BC34A;
#         }
#     </style>
# </head>
#
# <body>
#     <div class="created-by">
#         Created by <a href="https://www.linkedin.com/in/abdullah-al-omar-galib-30b6b1258">Abdullah Al Omar Galib (Ahkatlio)</a>
#     </div>
# </body>
#
# </html>
