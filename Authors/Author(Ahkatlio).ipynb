# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>About the Author</title>
#     <style>
#         body {
#             font-family: 'Jost', sans-serif;
#             margin: 0;
#             padding: 0;
#             background: linear-gradient(#87CEFA, #90EE90);
#         }
#         .container {
#             max-width: 800px;
#             margin: 0 auto;
#             background: linear-gradient(to bottom, #b3d9ff, #b3ffb3);
#             padding: 50px;
#             border-radius: 10px;
#             box-shadow: 0 0 10px rgba(0, 0, 0, 0.2);
#         }
#         .profile-img {
#             display: block;
#             margin: 0 auto;
#             width: 200px;
#             height: 200px;
#             border-radius: 50%;
#             box-shadow: 0 0 10px rgba(0, 0, 0, 0.2);
#             transition: transform 0.3s ease;
#         }
#         .profile-img:hover {
#             transform: scale(1.1);
#         }
#         h1 {
#             text-align: center;
#             color: orange;
#             margin-top: 30px;
#         }
#         p {
#             text-align: justify;
#             line-height: 1.5;
#             margin-top: 20px;
#             color: #333;
#         }
#         a {
#             color: blue;
#             text-decoration: none;
#         }
#         a:hover {
#             color: #fff;
#         }
#         .button {
#             display: inline-block;
#             padding: 10px 20px;
#             background-color: #fff;
#             color: #333;
#             border-radius: 5px;
#             text-decoration: none;
#             transition: background-color 0.3s ease;
#         }
#         .button:hover {
#             background-color: #333;
#             color: #fff;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <img class="profile-img" src="Authors_img/Ahkatlio.jpg" alt="Profile Picture">
#         <h1>About Abdullah Al Omar Galib (Ahkatlio)</h1>
#         <p>I'm a high school student who loves coding, quantum computing, music, physics, math, paintings, and more. I enjoy learning and teaching new things.</p>
#         <p>For more information, please visit my <a href="https://www.linkedin.com/in/abdullah-al-omar-galib-30b6b1258/">LinkedIn profile</a>.</p>
#     </div>
# </body>
# </html>
