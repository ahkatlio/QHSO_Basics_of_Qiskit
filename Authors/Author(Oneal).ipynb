# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <title>About the Author</title>
#     <style>
#         body {
#             font-family: 'Jost', sans-serif;
#             margin: 0;
#             padding: 0;
#             background-size: cover;
#             background-position: center;
#             background-repeat: no-repeat;
#         }
#         .container {
#             max-width: 800px;
#             margin: 0 auto;
#             background: linear-gradient(to bottom, #87CEFA, #90EE90);
#             padding: 50px;
#             border-radius: 10px;
#             box-shadow: 0 0 10px rgba(0, 0, 0, 0.2);
#         }
#         .profile-img {
#             display: block;
#             margin: 0 auto;
#             width: 200px;
#             height: 200px;
#             border-radius: 50%;
#             box-shadow: 0 0 10px rgba(0, 0, 0, 0.2);
#             transition: transform 0.3s ease;
#         }
#         .profile-img:hover {
#             transform: scale(1.1);
#         }
#         h1 {
#             text-align: center;
#             color: orange;
#             margin-top: 30px;
#             text-shadow: 2px 2px 4px #000000;
#         }
#         p {
#             text-align: justify;
#             line-height: 1.5;
#             margin-top: 20px;
#             color: #333;
#         }
#         a {
#             color: blue;
#             text-decoration: none;
#             text-shadow: 2px 2px 4px #000000;
#         }
#         a:hover {
#             color: #f1c40f;
#         }
#         .button {
#             display: inline-block;
#             padding: 10px 20px;
#             background-color: #fff;
#             color: #333;
#             border-radius: 5px;
#             text-decoration: none;
#             transition: background-color 0.3s ease;
#         }
#         .button:hover {
#             background-color: #333;
#             color: #fff;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <img class="profile-img" src="Authors_img/OnealWang.png" alt="Profile Picture">
#         <h1>About Oneal Wang</h1>
#         <p>Oneal Wang is the founder of Quantum High School Organization and he has dedicated most of his studies towards physics. As the president and founder of the Sage Hill Physics team, Team “Sagacious” placed 47th internationally in the OnlinePhysicsBrawl competition in addition to participating in the F=ma and physics bowl. As the founder, Oneal believes in the mission of this non-profit organization to educate students worldwide about the impact of quantum information and quantum mechanics. In addition, mastering python, java, and julia has enabled him to assist his school’s robotics team in the FRC competition and developing an AI algorithm for spectral classification. Applying these skills helped him advance in the U.S. Astronomy and Astrophysics Olympiad as well as many current projects he is currently working on. Otherwise, Star Wars and swim takes up most of his time.</p>
#         <p>For more information, please visit his <a href="https://www.linkedin.com/in/oneal-wang-a70565273/">LinkedIn profile</a>.</p>
#     </div>
# </body>
# </html>
